# %%
import tensorflow as tf 
# import matplotlib.pyplot as plt 
import cv2 
import numpy as np 
# import os 
# import time
# Out:
# 2023-04-03 15:19:42.873477: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 15:19:45.167984: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/abk/miniconda3/envs/tf/lib/
# 2023-04-03 15:19:45.168497: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/abk/miniconda3/envs/tf/lib/
# 2023-04-03 15:19:45.168526: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
VIDEO_LINK = 'elephant-attack.mp4'
class_names = ['bird', 'elephant', 'person', 'wild_boar']
img_height , img_width , color_mode = 180,180,"grayscale"
model = tf.keras.models.load_model('./trained_models/model-0.8748-(h-det).h5')
# Out:
# 2023-04-03 15:19:47.691391: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 15:19:47.711431: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 15:19:47.712057: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 15:19:47.712760: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 15:19:47.713988: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 15:19:47.714899: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 15:19:47.715383: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 15:19:49.004671: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 15:19:49.005549: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 15:19:49.005785: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 15:19:49.005926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3356 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
def detect_animal(frame) : 
    # print(frame.shape)
    img_array = np.array(frame)
    img_array = cv2.resize(img_array,(img_width,img_height))
    img_array = cv2.cvtColor(img_array,cv2.COLOR_BGR2GRAY)
    img_array = tf.expand_dims(img_array, 0)
    # print(img_array.shape)

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    prediction_animal = class_names[score.numpy().argmax()]
    prediction_percent = np.max(score.numpy())
    # print(prediction_animal , prediction_percent)
    return prediction_animal,prediction_percent

# %%
video = cv2.VideoCapture(VIDEO_LINK)
fps = int(video.get(cv2.CAP_PROP_FPS))
frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
while True : 
    ret,frame  = video.read()
    if ret :
        cv2.imshow('frame', frame)
        animal , confidence = detect_animal(frame)
        print(animal,confidence)
            
        
      

        if cv2.waitKey(30) == ord('q') : 
            break
    else : 
        break
# Out:
# 2023-04-03 15:19:51.175674: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 1/1 [==============================] - 2s 2s/step
# wild_boar 0.9999974
# 1/1 [==============================] - 0s 19ms/step
# wild_boar 0.9999974
# 1/1 [==============================] - 0s 19ms/step
# wild_boar 0.9999932
# 1/1 [==============================] - 0s 21ms/step
# wild_boar 0.9999932
# 1/1 [==============================] - 0s 22ms/step
# wild_boar 0.9966689
# 1/1 [==============================] - 0s 23ms/step
# wild_boar 0.9966808
# 1/1 [==============================] - 0s 19ms/step
# wild_boar 0.9939283
# 1/1 [==============================] - 0s 21ms/step
# wild_boar 0.99391395
# 1/1 [==============================] - 0s 24ms/step
# wild_boar 0.9991879
# 1/1 [==============================] - 0s 21ms/step
# wild_boar 0.9991854
# 1/1 [==============================] - 0s 22ms/step
# wild_boar 0.9999869
# 1/1 [==============================] - 0s 20ms/step
# wild_boar 0.9999869
# 1/1 [==============================] - 0s 22ms/step
# wild_boar 0.99997115
# 1/1 [==============================] - 0s 24ms/step
# wild_boar 0.99997115
# 1/1 [==============================] - 0s 21ms/step
# wild_boar 0.9999933
# 1/1 [==============================] - 0s 20ms/step
# wild_boar 0.99999356
# 1/1 [==============================] - 0s 30ms/step
# wild_boar 0.99999166
# 1/1 [==============================] - 0s 21ms/step
# wild_boar 0.99999154
# 1/1 [==============================] - 0s 25ms/step
# wild_boar 0.99997663
# 1/1 [==============================] - 0s 23ms/step
# wild_boar 0.99997663
# 1/1 [==============================] - 0s 20ms/step
# wild_boar 0.995021
# 1/1 [==============================] - 0s 22ms/step
# wild_boar 0.9950958
# 1/1 [==============================] - 0s 20ms/step
# wild_boar 0.9827324
# 1/1 [==============================] - 0s 22ms/step
# wild_boar 0.982832
# 1/1 [==============================] - 0s 19ms/step
# wild_boar 0.6027664
# 1/1 [==============================] - 0s 21ms/step
# wild_boar 0.6049151
# 1/1 [==============================] - 0s 43ms/step
# wild_boar 0.5430138
# 1/1 [==============================] - 0s 24ms/step
# wild_boar 0.53524977
# 1/1 [==============================] - 0s 37ms/step
# bird 0.7576379
# 1/1 [==============================] - 0s 25ms/step
# bird 0.74947906
# 1/1 [==============================] - 0s 21ms/step
# bird 0.98093855
# 1/1 [==============================] - 0s 20ms/step
# bird 0.98112124
# 1/1 [==============================] - 0s 18ms/step
# wild_boar 0.9952304
# 1/1 [==============================] - 0s 21ms/step
# wild_boar 0.99516845
# 1/1 [==============================] - 0s 19ms/step
# wild_boar 0.9997814
# 1/1 [==============================] - 0s 19ms/step
# wild_boar 0.9997838
# 1/1 [==============================] - 0s 22ms/step
# wild_boar 0.9952579
# 1/1 [==============================] - 0s 23ms/step
# wild_boar 0.99544734
# 1/1 [==============================] - 0s 20ms/step
# wild_boar 0.96830016
# 1/1 [==============================] - 0s 20ms/step
# wild_boar 0.9715497
# 1/1 [==============================] - 0s 18ms/step
# wild_boar 0.9999268
# 1/1 [==============================] - 0s 20ms/step
# wild_boar 0.9999305
# 1/1 [==============================] - 0s 27ms/step
# wild_boar 0.96587956
# 1/1 [==============================] - 0s 26ms/step
# wild_boar 0.9683966
# 1/1 [==============================] - 0s 28ms/step
# person 0.5402056
# 1/1 [==============================] - 0s 24ms/step
# person 0.53760314
# 1/1 [==============================] - 0s 31ms/step
# person 0.763875
# 1/1 [==============================] - 0s 26ms/step
# person 0.7552796
# 1/1 [==============================] - 0s 27ms/step
# person 0.53290987
# 1/1 [==============================] - 0s 20ms/step
# person 0.532765
# 1/1 [==============================] - 0s 21ms/step
# person 0.7670719
# 1/1 [==============================] - 0s 21ms/step
# person 0.7678228
# 1/1 [==============================] - 0s 23ms/step
# bird 0.42612547
# 1/1 [==============================] - 0s 19ms/step
# bird 0.42330176
# 1/1 [==============================] - 0s 21ms/step
# bird 0.93176514
# 1/1 [==============================] - 0s 24ms/step
# bird 0.9360215
# 1/1 [==============================] - 0s 29ms/step
# bird 0.6235851
# 1/1 [==============================] - 0s 28ms/step
# bird 0.6327643
# 1/1 [==============================] - 0s 33ms/step
# bird 0.98701376
# 1/1 [==============================] - 0s 29ms/step
# bird 0.9871486
# 1/1 [==============================] - 0s 22ms/step
# person 0.9706243
# 1/1 [==============================] - 0s 21ms/step
# person 0.9704833
# 1/1 [==============================] - 0s 19ms/step
# person 0.7736421
# 1/1 [==============================] - 0s 25ms/step
# person 0.7675922
# 1/1 [==============================] - 0s 28ms/step
# wild_boar 0.9271702
# 1/1 [==============================] - 0s 28ms/step
# wild_boar 0.92741686
# 1/1 [==============================] - 0s 29ms/step
# wild_boar 0.995432
# 1/1 [==============================] - 0s 25ms/step
# wild_boar 0.99545187
# 1/1 [==============================] - 0s 18ms/step
# bird 0.501101
# 1/1 [==============================] - 0s 21ms/step
# bird 0.50134706
# 1/1 [==============================] - 0s 19ms/step
# person 0.90850145
# 1/1 [==============================] - 0s 25ms/step
# person 0.91543055
# 1/1 [==============================] - 0s 26ms/step
# person 0.9977785
# 1/1 [==============================] - 0s 28ms/step
# person 0.9978098
# 1/1 [==============================] - 0s 22ms/step
# person 0.9994288
# 1/1 [==============================] - 0s 29ms/step
# person 0.99942064
# 1/1 [==============================] - 0s 18ms/step
# person 0.99491984
# 1/1 [==============================] - 0s 23ms/step
# person 0.9949173
# 1/1 [==============================] - 0s 28ms/step
# person 0.9760696
# 1/1 [==============================] - 0s 20ms/step
# person 0.97616595
# 1/1 [==============================] - 0s 20ms/step
# person 0.84712803
# 1/1 [==============================] - 0s 25ms/step
# person 0.83874625
# 1/1 [==============================] - 0s 22ms/step
# person 0.9986395
# 1/1 [==============================] - 0s 21ms/step
# person 0.9986626
# 1/1 [==============================] - 0s 22ms/step
# person 0.997997
# 1/1 [==============================] - 0s 21ms/step
# person 0.99802303
# 1/1 [==============================] - 0s 19ms/step
# person 0.9624304
# 1/1 [==============================] - 0s 22ms/step
# person 0.96427673
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.5666496
# 1/1 [==============================] - 0s 32ms/step
# elephant 0.5617438
# 1/1 [==============================] - 0s 26ms/step
# elephant 0.8448717
# 1/1 [==============================] - 0s 23ms/step
# elephant 0.8466069
# 1/1 [==============================] - 0s 23ms/step
# person 0.8246224
# 1/1 [==============================] - 0s 28ms/step
# person 0.8285647
# 1/1 [==============================] - 0s 19ms/step
# person 0.9983468
# 1/1 [==============================] - 0s 22ms/step
# person 0.9983364
# 1/1 [==============================] - 0s 28ms/step
# person 0.9987884
# 1/1 [==============================] - 0s 20ms/step
# person 0.9987601
# 1/1 [==============================] - 0s 21ms/step
# person 0.984211
# 1/1 [==============================] - 0s 25ms/step
# person 0.9840267
# 1/1 [==============================] - 0s 20ms/step
# elephant 0.7793543
# 1/1 [==============================] - 0s 20ms/step
# elephant 0.78175676
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.92940605
# 1/1 [==============================] - 0s 23ms/step
# elephant 0.9281863
# 1/1 [==============================] - 0s 27ms/step
# elephant 0.97276425
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.97289366
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.93135476
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.92892337
# 1/1 [==============================] - 0s 23ms/step
# person 0.56751925
# 1/1 [==============================] - 0s 24ms/step
# person 0.63609385
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.63678265
# 1/1 [==============================] - 0s 18ms/step
# elephant 0.6330248
# 1/1 [==============================] - 0s 21ms/step
# person 0.5485736
# 1/1 [==============================] - 0s 19ms/step
# person 0.5885075
# 1/1 [==============================] - 0s 23ms/step
# elephant 0.6921613
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.7053951
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.69549286
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.6986195
# 1/1 [==============================] - 0s 24ms/step
# person 0.6747707
# 1/1 [==============================] - 0s 23ms/step
# person 0.6754526
# 1/1 [==============================] - 0s 24ms/step
# person 0.84769076
# 1/1 [==============================] - 0s 20ms/step
# person 0.84685886
# 1/1 [==============================] - 0s 19ms/step
# person 0.4518672
# 1/1 [==============================] - 0s 19ms/step
# person 0.44952744
# 1/1 [==============================] - 0s 20ms/step
# elephant 0.7032835
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.7018926
# 1/1 [==============================] - 0s 21ms/step
# elephant 0.77031136
# 1/1 [==============================] - 0s 23ms/step
# elephant 0.7704447
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.9695301
# 1/1 [==============================] - 0s 21ms/step
# elephant 0.9713089
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.9442777
# 1/1 [==============================] - 0s 24ms/step
# elephant 0.94354385
# 1/1 [==============================] - 0s 23ms/step
# elephant 0.9969183
# 1/1 [==============================] - 0s 20ms/step
# elephant 0.9965733
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.998765
# 1/1 [==============================] - 0s 23ms/step
# elephant 0.9987457
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.99907184
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.9990113
# 1/1 [==============================] - 0s 21ms/step
# elephant 0.9898665
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.9898662
# 1/1 [==============================] - 0s 20ms/step
# elephant 0.99116266
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.9922975
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.99918157
# 1/1 [==============================] - 0s 21ms/step
# elephant 0.9991762
# 1/1 [==============================] - 0s 20ms/step
# elephant 0.999323
# 1/1 [==============================] - 0s 20ms/step
# elephant 0.99931824
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.9933293
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.9933084
# 1/1 [==============================] - 0s 20ms/step
# elephant 0.9763901
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.97618526
# 1/1 [==============================] - 0s 24ms/step
# elephant 0.9970584
# 1/1 [==============================] - 0s 19ms/step
# elephant 0.9970476
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.96845824
# 1/1 [==============================] - 0s 26ms/step
# elephant 0.9581201
# 1/1 [==============================] - 0s 22ms/step
# elephant 0.9761521
# 1/1 [==============================] - 0s 21ms/step
# elephant 0.97597957
# 1/1 [==============================] - 0s 26ms/step
# elephant 0.9930379
# 1/1 [==============================] - 0s 18ms/step
# elephant 0.9929792
# 1/1 [==============================] - 0s 21ms/step
# elephant 0.99974984
# 1/1 [==============================] - 0s 21ms/step
# elephant 0.9997515
# 1/1 [==============================] - 0s 21ms/step
# elephant 0.99747014
# 1/1 [==============================] - 0s 23ms/step
# elephant 0.99749607
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
