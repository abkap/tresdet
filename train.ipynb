# %%
import tensorflow as tf 
from tensorflow import keras 
import numpy as np 
import matplotlib.pyplot as plt
import os

# %%
cwd = os.getcwd()
dataset = "bird-detection-tfrecord\\train"
train_dataset = os.path.join(cwd,dataset,"bird.tfrecord")
image_description_map = os.path.join(cwd,dataset,"bird_label_map.pbtxt")
print(train_dataset)
# Out:
# e:\dataset\main_project\bird-detection-tfrecord\train\bird.tfrecord

# %%
raw_dataset = tf.data.TFRecordDataset([train_dataset])
print(image_description_map)

# for raw_record in raw_dataset.take(1):
#     example = tf.train.Example()
#     example.ParseFromString(raw_record.numpy())
#     print(type(example))
# Out:
# e:\dataset\main_project\bird-detection-tfrecord\train\bird_label_map.pbtxt

# %%
for string_record in raw_dataset:
    example = tf.train.Example()
    example.ParseFromString(string_record.numpy())
    img  = example.features.feature["encoded"].bytes_list.value
    
    print(img)

    # save image to file
    # ...
